# %% [markdown]
# # 이진분류 종합실습 : 이직 예측

# %% [markdown]
# * 회사 인사팀에서는 AIVLER 들에게 직원의 이직여부과 관련해서 분석을 요청하였습니다.
# * 최근 이직율이 증가하는 것에 대해 우려를 갖고 있기에, 이직여부에 영향을 주는 요인에 대해 분석하여, 이직할 것으로 보이는 직원들에 대해 회사를 떠나지 않도록 인사 프로그램을 준비하려고 합니다.
# * 어떤 직원이 이직할지 예측해 봅시다.

# %% [markdown]
# ![](https://adoptostaging.blob.core.windows.net/media/employee-attrition-reasons-9LIqMv.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_train_validation.CSV"
data = pd.read_csv(path)
data['Attrition'] = np.where(data['Attrition']=='Yes', 1, 0)
data.head(10)
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   33      Travel_Rarely  Research & Development
# 1          0   35  Travel_Frequently  Research & Development
# 2          0   42      Travel_Rarely  Research & Development
# 3          0   46      Travel_Rarely                   Sales
# 4          0   39  Travel_Frequently                   Sales
# 5          1   22  Travel_Frequently  Research & Development
# 6          0   24      Travel_Rarely  Research & Development
# 7          0   34      Travel_Rarely  Research & Development
# 8          0   30      Travel_Rarely  Research & Development
# 9          0   26      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 7          3           Medical             817
# 1                18          2     Life Sciences            1412
# 2                 6          3           Medical            1911
# 3                 2          3         Marketing            1204
# 4                20          3     Life Sciences            1812
# 5                 4          1  Technical Degree             593
# 6                21          2  Technical Degree            1551
# 7                 8          3           Medical            2068
# 8                20          3             Other            1084
# 9                 6          3     Life Sciences             686
#
#    EnvironmentSatisfaction  Gender  ...  OverTime PercentSalaryHike  \
# 0                        3    Male  ...        No                11
# 1                        3    Male  ...        No                11
# 2                        3    Male  ...        No                13
# 3                        3  Female  ...        No                23
# 4                        3    Male  ...        No                18
# 5                        3    Male  ...        No                16
# 6                        3    Male  ...        No                14
# 7                        2    Male  ...        No                12
# 8                        3    Male  ...        No                15
# 9                        3  Female  ...       Yes                13
#
#    RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                         4                0                 14
# 1                         3                0                 10
# 2                         2                1                 18
# 3                         1                0                 28
# 4                         4                1                  7
# 5                         3                0                  4
# 6                         2                3                  2
# 7                         1                0                  6
# 8                         3                1                  7
# 9                         3                1                  3
#
#    TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      3               4              13                   9
# 1                      2               3               2                   2
# 2                      3               4              13                   7
# 3                      2               3              26                  15
# 4                      6               3               2                   1
# 5                      3               3               2                   2
# 6                      3               3               1                   1
# 7                      3               4               4                   3
# 8                      1               2               6                   2
# 9                      2               3               3                   2
#
#    YearsWithCurrManager
# 0                     7
# 1                     2
# 2                     7
# 3                     9
# 4                     2
# 5                     2
# 6                     0
# 7                     2
# 8                     2
# 9                     2
#
# [10 rows x 26 columns]

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EmployeeNumber	|	사번	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	| Single, Married, Divorced		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	OverTime	|	야근여부	|	범주	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %% [markdown]
# ----

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 데이터 정리

# %%
target = 'Attrition'

# %%
# 불필요한 변수 제거
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %%
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화
# * 범주형 데이터이면서 값이 0,1 로 되어 있는 것이 아니라면, 가변수화를 수행해야 합니다.
# * 대상이 되는 변수에 대해서 가변수화를 수행해주세요.

# %%
dum_cols = ['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender',
            'JobRole', 'JobInvolvement', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction',
            'StockOptionLevel','WorkLifeBalance' ]

x = pd.get_dummies(x, columns = dum_cols ,drop_first = True)
x.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   33                 7          11691                   0
# 1   35                18           9362                   2
# 2   42                 6          13348                   9
# 3   46                 2          17048                   8
# 4   39                20           4127                   2
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                 14                      3
# 1                 11                 10                      2
# 2                 13                 18                      3
# 3                 23                 28                      2
# 4                 18                  7                      6
#
#    YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  ...  \
# 0              13                   9                     7  ...
# 1               2                   2                     2  ...
# 2              13                   7                     7  ...
# 3              26                  15                     9  ...
# 4               2                   1                     2  ...
#
#    OverTime_Yes  RelationshipSatisfaction_2  RelationshipSatisfaction_3  \
# 0         False                       False                       False
# 1         False                       False                        True
# 2         False                        True                       False
# 3         False                       False                       False
# 4         False                       False                       False
#
#    RelationshipSatisfaction_4  StockOptionLevel_1  StockOptionLevel_2  \
# 0                        True               False               False
# 1                       False               False               False
# 2                       False                True               False
# 3                       False               False               False
# 4                        True                True               False
#
#    StockOptionLevel_3  WorkLifeBalance_2  WorkLifeBalance_3  WorkLifeBalance_4
# 0               False              False              False               True
# 1               False              False               True              False
# 2               False              False              False               True
# 3               False              False               True              False
# 4               False              False               True              False
#
# [5 rows x 53 columns]

# %% [markdown]
# ### (3) 데이터 분할
# * train_test_split :
#     * test_size : 0.# - 비율로 분할, 1보다 큰 자연수 - 갯수로 분할
#     * train_size로 지정도 가능.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 200, random_state = 2022)

# %% [markdown]
# ### (4) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 4.모델링

# %% [markdown]
# ### (1) 모델1
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 53

# %%
#메모리 초기화
clear_session()

#모델 설정
model = Sequential([Dense(25, input_shape = (nfeatures,), activation = 'relu'),
                    Dense(12, activation = 'relu'),
                    Dense(6, activation = 'relu'),
                    Dense(1,activation = 'sigmoid')]
                   )

#모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 25)                1350
#
#  dense_1 (Dense)             (None, 12)                312
#
#  dense_2 (Dense)             (None, 6)                 78
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 1747 (6.82 KB)
# Trainable params: 1747 (6.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
history = model.fit(x_train, y_train, epochs = 100, validation_split = .2, verbose = 0).history

# %%
dl_history_plot(history)

# %%
pred = model.predict(x_val)
pred = np.where(pred >= .5, 1, 0)

print(confusion_matrix(y_val,pred))
print(classification_report(y_val,pred))
# Out:
# 7/7 [==============================] - 0s 2ms/step
# [[155  14]
#  [ 12  19]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       169
#            1       0.58      0.61      0.59        31
#
#     accuracy                           0.87       200
#    macro avg       0.75      0.77      0.76       200
# weighted avg       0.87      0.87      0.87       200

# %%
print(data['Attrition'].value_counts(normalize = True))
sns.countplot( x='Attrition',data=data)
plt.grid()
plt.show()
# Out:
# Attrition
# 0    0.84
# 1    0.16
# Name: proportion, dtype: float64

# %% [markdown]
# ### (2) 모델2 : resampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler()
x_train_ros, y_train_ros = ros.fit_resample(x_train, y_train)

# %%
#메모리 초기화
clear_session()

#모델 설정
model2 = Sequential([Dense(25, input_shape = (nfeatures,), activation = 'relu'),
                    Dense(12, activation = 'relu'),
                    Dense(6, activation = 'relu'),
                    Dense(1,activation = 'sigmoid')]
                   )

#모델 요약
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 25)                1350
#
#  dense_1 (Dense)             (None, 12)                312
#
#  dense_2 (Dense)             (None, 6)                 78
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 1747 (6.82 KB)
# Trainable params: 1747 (6.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2.compile(optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
history2 = model2.fit(x_train_ros, y_train_ros, epochs = 100, validation_split = .2).history
# Out:
# Epoch 1/100
# 45/45 [==============================] - 2s 11ms/step - loss: 0.7018 - val_loss: 0.6754
# Epoch 2/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6775 - val_loss: 0.6657
# Epoch 3/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.6453 - val_loss: 0.6402
# Epoch 4/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5720 - val_loss: 0.7190
# Epoch 5/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5003 - val_loss: 0.7970
# Epoch 6/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4735 - val_loss: 0.6645
# Epoch 7/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4525 - val_loss: 0.7077
# Epoch 8/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4388 - val_loss: 0.6449
# Epoch 9/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4266 - val_loss: 0.6537
# Epoch 10/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4218 - val_loss: 0.6051
# Epoch 11/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4063 - val_loss: 0.6821
# Epoch 12/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3954 - val_loss: 0.5487
# Epoch 13/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3878 - val_loss: 0.5947
# Epoch 14/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.3705 - val_loss: 0.6093
# Epoch 15/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3568 - val_loss: 0.5952
# Epoch 16/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3451 - val_loss: 0.6240
# Epoch 17/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3286 - val_loss: 0.4703
# Epoch 18/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3159 - val_loss: 0.5087
# Epoch 19/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2977 - val_loss: 0.4930
# Epoch 20/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2780 - val_loss: 0.4360
# Epoch 21/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2665 - val_loss: 0.4564
# Epoch 22/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2473 - val_loss: 0.4309
# Epoch 23/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2281 - val_loss: 0.4946
# Epoch 24/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2156 - val_loss: 0.5470
# Epoch 25/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2028 - val_loss: 0.5500
# Epoch 26/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1985 - val_loss: 0.3840
# Epoch 27/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1822 - val_loss: 0.4121
# Epoch 28/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1693 - val_loss: 0.3261
# Epoch 29/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1591 - val_loss: 0.3576
# Epoch 30/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1523 - val_loss: 0.3622
# Epoch 31/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1419 - val_loss: 0.2909
# Epoch 32/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1387 - val_loss: 0.2520
# Epoch 33/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1260 - val_loss: 0.2406
# Epoch 34/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1149 - val_loss: 0.3152
# Epoch 35/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1128 - val_loss: 0.2747
# Epoch 36/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1049 - val_loss: 0.1375
# Epoch 37/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0953 - val_loss: 0.2326
# Epoch 38/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0855 - val_loss: 0.1157
# Epoch 39/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0926 - val_loss: 0.1247
# Epoch 40/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0766 - val_loss: 0.1372
# Epoch 41/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0725 - val_loss: 0.2075
# Epoch 42/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0675 - val_loss: 0.1219
# Epoch 43/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0708 - val_loss: 0.1292
# Epoch 44/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0577 - val_loss: 0.0982
# Epoch 45/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0548 - val_loss: 0.1448
# Epoch 46/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0515 - val_loss: 0.0841
# Epoch 47/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0488 - val_loss: 0.0918
# Epoch 48/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0432 - val_loss: 0.0894
# Epoch 49/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0396 - val_loss: 0.0657
# Epoch 50/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0387 - val_loss: 0.1116
# Epoch 51/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0365 - val_loss: 0.0901
# Epoch 52/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0328 - val_loss: 0.0576
# Epoch 53/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0287 - val_loss: 0.0351
# Epoch 54/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0284 - val_loss: 0.0357
# Epoch 55/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0259 - val_loss: 0.0269
# Epoch 56/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0258 - val_loss: 0.0744
# Epoch 57/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0376 - val_loss: 0.0371
# Epoch 58/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0457
# Epoch 59/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0205 - val_loss: 0.0242
# Epoch 60/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0511
# Epoch 61/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0267
# Epoch 62/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0702
# Epoch 63/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0461 - val_loss: 0.0508
# Epoch 64/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0536
# Epoch 65/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0207
# Epoch 66/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.0105
# Epoch 67/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0665
# Epoch 68/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0221
# Epoch 69/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0118 - val_loss: 0.0158
# Epoch 70/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0118
# Epoch 71/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0134
# Epoch 72/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0133
# Epoch 73/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0121
# Epoch 74/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0097
# Epoch 75/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0103 - val_loss: 0.0125
# Epoch 76/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0094
# Epoch 77/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 78/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0127
# Epoch 79/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0093
# Epoch 80/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0054 - val_loss: 0.0103
# Epoch 81/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0112
# Epoch 82/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 83/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 84/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 85/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0065
# Epoch 86/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0065
# Epoch 87/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 88/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0064
# Epoch 89/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0095
# Epoch 90/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0062
# Epoch 91/100
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0038 - val_loss: 0.0074
# Epoch 92/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0084
# Epoch 93/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0060
# Epoch 94/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0055
# Epoch 95/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 96/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 97/100
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 98/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 99/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 100/100
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0039

# %%
dl_history_plot(history2)

# %%
pred2 = model2.predict(x_val)
pred2 = np.where(pred2 >= 0.5, 1, 0)

print(confusion_matrix(y_val,pred2))
print(classification_report(y_val,pred2))
# Out:
# 7/7 [==============================] - 0s 2ms/step
# [[154  15]
#  [ 12  19]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       169
#            1       0.56      0.61      0.58        31
#
#     accuracy                           0.86       200
#    macro avg       0.74      0.76      0.75       200
# weighted avg       0.87      0.86      0.87       200
